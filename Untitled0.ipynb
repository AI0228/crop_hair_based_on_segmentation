# %%
cd drive/MyDrive/2D-Human-Parsing-main/
# Out:
# /content/drive/MyDrive/2D-Human-Parsing-main

# %%
# !python inference.py --input_image 2.jpg
# Out:
# Constructing DeepLabv3+ model...
# Number of classes: 20
# Output stride: 16
# Number of Input Channels: 3
# ...
